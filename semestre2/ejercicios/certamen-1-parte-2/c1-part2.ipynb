# %%
import numpy as np
f1 = lambda x: 4.*np.power(x,4.) - 6*np.power(x,2.) - (11/4)

x_0=(1.5)

f1_der = lambda x: 16.*np.power(x,3.)-12.*x
x_i=x_0
for i in range(10):
    
    sig= x_i -(f1(x_i)/f1_der(x_i))

    x_i=sig

x_i
# Out:
# np.float64(1.3667603991738622)

# %%
f2 = lambda x: 8.*np.power(x,4.) - 12.*np.power(x,3.) + 6.*np.power(x,2.)-x

f2_der = lambda x: 32.*np.power(x,3.) - 36.*np.power(x,2.)+12.*x-1.

x1=0
x2=0.5

x_i=x2
for i in range(10):
    
    sig= x_i -(f2(x_i)/f2_der(x_i))

    x_i=sig
    

x_i
# Out:
# C:\Users\javie\AppData\Local\Temp\ipykernel_30088\4252697841.py:11: RuntimeWarning: invalid value encountered in scalar divide
#   sig= x_i -(f2(x_i)/f2_der(x_i))
# np.float64(nan)

# %%
x3 = 96*(1/4) -72*0.5 +12
x3
x4 = 96*2*(0.5)-72
x4
# Out:
# 24.0

# %%
g1 =lambda x: 32.*np.power(x,3.) - 36.*np.power(x,2.)+12.*x
g1(0.5)
# Out:
# np.float64(1.0)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def found_arc_cos(x):
    if(x == 1):
        return 0
    elif (x==-1):
        return -1
    y_i=np.pi/2

    f1= lambda y: -x + np.cos(y) + y
    x_1 = f1(y_i)
    x_2 = f2(y_i+0.5)
    while (error > 10e-6):
        error = x_1/x_2
        x_sig = f1()   



    return arc_cos

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
f_x = lambda t,a,b: 0.5*((b-a)*np.sin(t)+a+b)
f_dx = lambda t,a,b: -0.5*(b-a)*np.cos(t)


def compute_bounded_root(fk,ak,bk,m):
    x0 = 1

    for i in range(m):
        #buenas

    return rk

##revisar codigo##
