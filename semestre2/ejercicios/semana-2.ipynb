# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Para cada tipo:
#
# $a)$ ¿Cuál es el primer entero no representable?
#
# $b)$ ¿Cuál es el valor del $\epsilon_{mach}$?
# R: La cantindad de bits de la mantisa en negativo
#
# $c)$ ¿Cuál es el menor número representable mayor a 0?
#
# $d)$ ¿En qué intervalo se mueve el exponente?

# %% [markdown]
# **Considerando la siguiente ecuación:**
# $x^{2} + b{x} + 1 = 0$
#
# **Para $b >> 1$. Utilizando la formula general:** $$x = \frac{-\beta\pm\sqrt{\beta^2
# -4\alpha\gamma}}{2\alpha}$$.

# %% [markdown]
# 1) ¿Existe algún problema en obtener ${x_+}$ para obtener $b \in [{2^2}, {2^{23}}]$ ?  Si existe, corregirlo.
# 2) ¿Existe algún problema en obtener ${x_+}$ para obtener $b \in [{2^{30}}, {2^{50}}]$ ?  Si existe, corregirlo.
# 3) ¿Qué ocurre para ${x_-}$ para $b \in  [{2^{30}}, {2^{50}}]$ ?
