# %%
import numpy as np

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Para encontral tal función simplifiquemos un poco la función que tenemos entre manos, como conocemos el $\hat{x} = 1$, podríamos simplemente reemplazarlo en la función $f(x)$ y obtendríamos lo siguiente:
#
# $f(y) = y  \sin(\log({y^{2}+1})-y)+x-1$
#
# Como se requiere aplicar el método de Newton requerimos conseguir la derivada de la función resultando, por lo que tendríamos lo siguiente:
#
# $f'(y) = \sin(\log({y^{2}+1})-y) + \frac{y  (\cos(\log({y^{2}+1})-y)) (2  y - y^2 -1)}{y^2+1}$
#
# Con esto ya podemos empezar a hacer cosas, requerimos saber que tipo de conversegencia tiene esta función pero dado el hecho que no contamos con el punto fijo no podremos hacerlo por el momento, se usarán 20 iteraciones para verificar la raíz exacta

# %%
f1 = lambda x,y: y*np.sin(np.log(np.power(y,2.)+1.)-y)+x-1.
f1_der = lambda y : np.sin(np.log(np.power(y,2.)+1.)-y) + (y*(np.cos(np.log(np.power(y,2.)+1.)-y))*(2.*y-np.power(y,2.)-1.))/(np.power(y,2.)+1.) 

def compute_function(x0,y0,m):
    yi=y0
    for _ in range(m):
        y_sig = yi - (f1(x0,yi))/(f1_der(yi))
        yi = y_sig
    return yi

# %%
compute_function(2,-6,4)
# Out:
# np.float64(-5.72841410372228)

# %% [markdown]
# Computación de la inversa:
#
# ![image.png](attachment:image.png)

# %%
f_lambda = lambda x,a: x * np.power(np.log(x),a) 
f_lambda_der = lambda x,a : np.power(np.log(x),a) + 3*np.power(np.log(x),2)

def obtener_x_min(f1,f2):



    return x_min
